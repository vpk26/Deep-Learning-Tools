# %%
import matplotlib.pyplot as plt
import os
import re
import shutil
import string
import tensorflow as tf
from tensorflow.keras import layers

# %%
# !wget : http://archive.ics.uci.edu/ml/machine-learning-databases/00228/smsspamcollection.zip
# Out:
# :: Scheme missing.
# --2022-06-12 18:09:46--  http://archive.ics.uci.edu/ml/machine-learning-databases/00228/smsspamcollection.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 203415 (199K) [application/x-httpd-php]
# Saving to: ‘smsspamcollection.zip’
#
# smsspamcollection.z 100%[===================>] 198.65K   694KB/s    in 0.3s
#
# 2022-06-12 18:09:46 (694 KB/s) - ‘smsspamcollection.zip’ saved [203415/203415]
#
# FINISHED --2022-06-12 18:09:46--
# Total wall clock time: 0.5s
# Downloaded: 1 files, 199K in 0.3s (694 KB/s)

# %%
# !unzip smsspamcollection.zip
# Out:
# Archive:  smsspamcollection.zip
#   inflating: SMSSpamCollection
#   inflating: readme

# %%
import pandas as pd

# %%
df = pd.read_csv("SMSSpamCollection", sep="\t", header=None)

# %%
df.head()
# Out:
#       0                                                  1
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
import numpy as np

# %%
#replacing the values for "ham" = 0 and "span" = 1 

for i in range(5572):
    if df[0][i] == "ham":
        df[0][i] = 0
    else:
        df[0][i] = 1

# %%
y = np.asarray(df[0]).astype('float32')

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df[1], y, test_size = 0.2)
x_train, x_valid, y_train, y_valid = train_test_split(x_train, y_train, train_size=0.8)

# %%
raw_train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
raw_test_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test))
raw_valid_dataset = tf.data.Dataset.from_tensor_slices((x_valid, y_valid))

# %%
def custom_standardization(input_data):
    lowercase = tf.strings.lower(input_data)
    stripped_html = tf.strings.regex_replace(lowercase, '<br />', ' ')
    return tf.strings.regex_replace(
        stripped_html,
        f'[{re.escape(string.punctuation)}]',
        ''
    )

# %%
# forming text to vector 
max_features = 10000
sequence_length = 250

vectorize_layer = layers.TextVectorization(
    standardize=custom_standardization,
    max_tokens=max_features,
    output_mode='int',
    output_sequence_length=sequence_length)
vectorize_layer.adapt(raw_train_dataset.map(lambda x, y: x))

# %%
def vectorize_text(text,label):
    text = tf.expand_dims(text,-1) # add an extra dimension to the text 
    return vectorize_layer(text),label

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = raw_train_dataset.batch(32).map(vectorize_text).cache().prefetch(buffer_size=AUTOTUNE)
val_ds = raw_valid_dataset.batch(32).map(vectorize_text).cache().prefetch(buffer_size=AUTOTUNE)
test_ds = raw_test_dataset.batch(32).map(vectorize_text).cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 250), dtype=tf.int64, name=None), TensorSpec(shape=(None,), dtype=tf.float32, name=None))>

# %%
model = tf.keras.Sequential([
    
    tf.keras.layers.Embedding(
        input_dim=len(vectorize_layer.get_vocabulary()),
        output_dim=32,
        # Use masking to handle the variable sequence lengths
        mask_zero=True),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64,return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1)
])

# %%
model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.Adam(1e-4),
              metrics=['accuracy'])

# %%
history = model.fit(train_ds, epochs=30,
                    validation_data=val_ds,
                  )
# Out:
# Epoch 1/30
# 112/112 [==============================] - 29s 103ms/step - loss: 0.6374 - accuracy: 0.8597 - val_loss: 0.4993 - val_accuracy: 0.8767
# Epoch 2/30
# 112/112 [==============================] - 7s 63ms/step - loss: 0.4102 - accuracy: 0.8597 - val_loss: 0.2293 - val_accuracy: 0.8767
# Epoch 3/30
# 112/112 [==============================] - 7s 63ms/step - loss: 0.1433 - accuracy: 0.9442 - val_loss: 0.1050 - val_accuracy: 0.9809
# Epoch 4/30
# 112/112 [==============================] - 7s 63ms/step - loss: 0.0655 - accuracy: 0.9871 - val_loss: 0.0863 - val_accuracy: 0.9809
# Epoch 5/30
# 112/112 [==============================] - 7s 63ms/step - loss: 0.0425 - accuracy: 0.9921 - val_loss: 0.0797 - val_accuracy: 0.9865
# Epoch 6/30
# 112/112 [==============================] - 8s 69ms/step - loss: 0.0295 - accuracy: 0.9941 - val_loss: 0.0795 - val_accuracy: 0.9865
# Epoch 7/30
# 112/112 [==============================] - 7s 63ms/step - loss: 0.0209 - accuracy: 0.9964 - val_loss: 0.0825 - val_accuracy: 0.9865
# Epoch 8/30
# 112/112 [==============================] - 7s 64ms/step - loss: 0.0154 - accuracy: 0.9978 - val_loss: 0.0891 - val_accuracy: 0.9843
# Epoch 9/30
# 112/112 [==============================] - 9s 83ms/step - loss: 0.0121 - accuracy: 0.9989 - val_loss: 0.0914 - val_accuracy: 0.9843
# Epoch 10/30
# 112/112 [==============================] - 7s 63ms/step - loss: 0.0096 - accuracy: 0.9992 - val_loss: 0.0946 - val_accuracy: 0.9821
# Epoch 11/30
# 112/112 [==============================] - 7s 63ms/step - loss: 0.0077 - accuracy: 0.9992 - val_loss: 0.1006 - val_accuracy: 0.9821
# Epoch 12/30
# 112/112 [==============================] - 7s 63ms/step - loss: 0.0060 - accuracy: 0.9994 - val_loss: 0.1125 - val_accuracy: 0.9809
# Epoch 13/30
# 112/112 [==============================] - 7s 63ms/step - loss: 0.0051 - accuracy: 0.9994 - val_loss: 0.1277 - val_accuracy: 0.9798
# Epoch 14/30
# 112/112 [==============================] - 7s 64ms/step - loss: 0.0045 - accuracy: 0.9994 - val_loss: 0.1350 - val_accuracy: 0.9798
# Epoch 15/30
# 112/112 [==============================] - 7s 63ms/step - loss: 0.0039 - accuracy: 0.9994 - val_loss: 0.1413 - val_accuracy: 0.9798
# Epoch 16/30
# 112/112 [==============================] - 7s 63ms/step - loss: 0.0035 - accuracy: 0.9997 - val_loss: 0.1474 - val_accuracy: 0.9798
# Epoch 17/30
# 112/112 [==============================] - 7s 63ms/step - loss: 0.0031 - accuracy: 0.9997 - val_loss: 0.1530 - val_accuracy: 0.9798
# Epoch 18/30
# 112/112 [==============================] - 7s 63ms/step - loss: 0.0028 - accuracy: 0.9997 - val_loss: 0.1582 - val_accuracy: 0.9798
# Epoch 19/30
# 112/112 [==============================] - 7s 64ms/step - loss: 0.0025 - accuracy: 0.9997 - val_loss: 0.1632 - val_accuracy: 0.9798
# Epoch 20/30
# 112/112 [==============================] - 7s 63ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1680 - val_accuracy: 0.9798
# Epoch 21/30
# 112/112 [==============================] - 7s 64ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1726 - val_accuracy: 0.9798
# Epoch 22/30
# 112/112 [==============================] - 7s 64ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1772 - val_accuracy: 0.9798
# Epoch 23/30
# 112/112 [==============================] - 7s 63ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1817 - val_accuracy: 0.9798
# Epoch 24/30
# 112/112 [==============================] - 7s 64ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1860 - val_accuracy: 0.9787
# Epoch 25/30
# 112/112 [==============================] - 7s 63ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1901 - val_accuracy: 0.9787
# Epoch 26/30
# 112/112 [==============================] - 7s 64ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1942 - val_accuracy: 0.9787
# Epoch 27/30
# 112/112 [==============================] - 7s 63ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1981 - val_accuracy: 0.9787
# Epoch 28/30
# 112/112 [==============================] - 7s 63ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2020 - val_accuracy: 0.9787
# Epoch 29/30
# 112/112 [==============================] - 7s 63ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2057 - val_accuracy: 0.9787
# Epoch 30/30
# 112/112 [==============================] - 8s 70ms/step - loss: 9.4651e-04 - accuracy: 1.0000 - val_loss: 0.2095 - val_accuracy: 0.9787

# %%
history = history.history

# %%
history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.figure(figsize=(15,5))
plt.subplot(121)
plt.title("Accuracy")
plt.plot(history["accuracy"],label="train acc")
plt.plot(history["val_accuracy"],label="val acc")
plt.legend()

plt.subplot(122)
plt.title("Loss")
plt.plot(history["loss"],label="train loss")
plt.plot(history["val_loss"],label="val loss")
plt.legend()

plt.show()
